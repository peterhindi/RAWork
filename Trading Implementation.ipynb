# %%
#from julia.api import Julia
import numpy as np
from juliacall import Main as jl
from juliacall import Pkg as jlPkg

jlPkg.activate("MyPack")  # relative path to the folder where `MyPack/Project.toml` should be used here 

jl.seval("using MyPack")

jl.MyPack.greet()

jl.MyPack.TSP_Pairs_Trade()
#jl.MyPack.TSP_Pairs_Trade()
# Out:
#   Activating project at `~/Github Repositories and Local Code/RAWork/MyPack`
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 12
#       8 jl.seval("using MyPack")
#      10 jl.MyPack.greet()
# ---> 12 jl.MyPack.TSP_Pairs_Trade()
#      13 #jl.MyPack.TSP_Pairs_Trade()
#
# File ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/any.jl:245, in __getattr__(self, k)
#     243         raise AttributeError(k)
#     244     else:
# --> 245         return self._jl_callmethod($(pyjl_methodnum(pyjlany_getattr)), k)
#     246 def __setattr__(self, k, v):
#     247     try:
#
# AttributeError: Julia: UndefVarError: `TSP_Pairs_Trade` not defined in `MyPack`
# Hello World!
