# %%
#from julia.api import Julia
import numpy as np
from juliacall import Main as jl
from juliacall import Pkg as jlPkg

jlPkg.activate("MyPack")  # relative path to the folder where `MyPack/Project.toml` should be used here 

jl.seval("using MyPack")

jl.MyPack.greet()
# Out:
#   Activating project at `~/Github Repositories and Local Code/RAWork/MyPack`
# Hello World!

# %%
#jl = Julia()
#from juliacall import Main as jl, convert as jlconvert
jl.gqreet()
#print(Main.test(10))
# Out:
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 #jl = Julia()
#       2 from juliacall import Main as jl, convert as jlconvert
# ----> 3 jl.include("test.ipynb")
#       4 #print(Main.test(10))
#
# File ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/any.jl:258, in __call__(self, *args, **kwargs)
#     256     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     257 def __call__(self, *args, **kwargs):
# --> 258     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     259 def __bool__(self):
#     260     return True
#
# JuliaError: LoadError: syntax: { } vector syntax is discontinued around /Users/peterhindi/Github Repositories and Local Code/RAWork/test.ipynb:1
# Stacktrace:
#  [1] top-level scope
#    @ ~/Github Repositories and Local Code/RAWork/test.ipynb:1
#  [2] include(fname::String)
#    @ Main ./sysimg.jl:38
#  [3] pyjlany_call(self::typeof(include), args_::Py, kwargs_::Py)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/any.jl:43
#  [4] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/base.jl:73
#  [5] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.JlWrap.Cjl ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/C.jl:63
# in expression starting at /Users/peterhindi/Github Repositories and Local Code/RAWork/test.ipynb:1
